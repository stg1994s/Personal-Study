# %%
import json
import requests
import re
import time
from collections import OrderedDict
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings(action='ignore')

url = 'http://www.yes24.com/24/category/bestseller'
headers = { }

# %%
allbooks2 = OrderedDict()
books2 = []
    
for i in range(1, 5+1):
    params = {'CategoryNumber':'001', 'sumgb':'09',
              'year':'2020', 'month':'10', 'PageNumber': i }
    res = requests.get(url, headers=headers, params=params)
    html = BeautifulSoup(res.text, 'lxml')
 
    # res.text[:300]

    titles = []
    writers = []
    pubs = []
    pubdates = []
    prices = []

    # 도서 제목 추출
    for title in html.select('td.goodsTxtInfo p:first-child'):
        # title = re.sub('\[도서\] ', '', title.text)
        titles.append(title.text.strip())
        #print(title.text.strip())

    # 저자
    for writer in html.select('div.aupu'):
        writer = writer.text.split('|')[0].strip()
        #print(writer)

        writers.append(writer.strip())

    # 출판사
    for pub in html.select('div.aupu'):
        pub = pub.text.split('|')[1].strip()
        # print(pub.strip())

        pubs.append(pub.strip())

    # 날짜
    for pubdate in html.select('div.aupu'):
        pubdate = pubdate.text.split('|')[2]
        # print(pubdate.strip())
        pubdates.append(pubdate.strip())

    # 가격
    for price in html.select('td.goodsTxtInfo p:nth-of-type(2)'):
        price = price.text.split('원')[0]
        price = re.sub(',', '', price)
        # print(price.strip())
        prices.append(price.strip())


    # 스크래핑한 도서목록을 json형식으로 재구성

    for i in range(len(titles)):
        book = OrderedDict()
        book['title'] = titles[i]
        book['writer'] = writers[i]
        book['pub'] = pubs[i]
        book['pubdate'] = pubdates[i]
        book['price'] = prices[i]
        books2.append(book)

    allbooks2['books2'] = books2
    print(json.dumps(allbooks2, ensure_ascii=False, indent=2))

    time.sleep(3)
    '''     '''
# 생성한 json 객체를 파일로 저장
with open('allbooks2.json', 'w', encoding='UTF8') as f:
    json.dump(allbooks2, f, ensure_ascii=False)

    #with open('allbooks2.json', encoding='UTF8')as f:
    #jbooks2 = json.load(f)
# Out:
# {
#   "books2": [
#     {
#       "title": "[도서]   이토록 공부가 재미있어지는 순간 : 공부에 지친 청소년들을 위한 힐링 에세이(30만 부 기념 Magic 에디션, 양장)",
#       "writer": "박성혁 저",
#       "pub": "다산북스",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   돈의 속성  : 최상위 부자가 말하는 돈에 대한 모든 것",
#       "writer": "김승호 저",
#       "pub": "스노우폭스북스",
#       "pubdate": "2020년 06월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   한번도 경험해보지 못한 나라 : \"민주주의는 어떻게 끝장나는가\"",
#       "writer": "강양구,권경애,김경율,서민,진중권 저",
#       "pub": "천년의상상",
#       "pubdate": "2020년 08월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   아몬드(양장)",
#       "writer": "손원평 저",
#       "pub": "창비",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   흔한남매의 흔한 호기심 1",
#       "writer": "흔한남매 원저/안치현 글/유난희 그림/이정모,흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   주식투자 무작정 따라하기 : 100만 왕초보가 감동한 최고의 주식투자 입문서(개정판)-길벗 무따기",
#       "writer": "윤재수 저",
#       "pub": "길벗",
#       "pubdate": "2020년 01월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   심판(양장,  마우스패드 증정 (포인트 차감))",
#       "writer": "베르나르 베르베르 저/전미연 역",
#       "pub": "열린책들",
#       "pubdate": "2020년 08월",
#       "price": "12800"
#     },
#     {
#       "title": "[도서]   존리의 부자되기 습관 : 대한민국 경제독립 액션 플랜(20만부 기념 리커버 에디션)",
#       "writer": "존리 저",
#       "pub": "지식노마드",
#       "pubdate": "2020년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 8 (양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   김미경의 리부트 : 코로나로 멈춘 나를 다시 일으켜 세우는 법",
#       "writer": "김미경 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 07월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   더 해빙 The Having (40만부 기념 리커버 에디션) : 부와 행운을 끌어당기는 힘(양장)",
#       "writer": "이서윤,홍주연 저",
#       "pub": "수오서재",
#       "pubdate": "2020년 03월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   만남은 지겹고 이별은 지쳤다 : 색과 체 산문집",
#       "writer": "색과 체 저",
#       "pub": "떠오름",
#       "pubdate": "2020년 06월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   기분이 태도가 되지 않게 : 기분 따라 행동하다 손해 보는 당신을 위한 심리 수업",
#       "writer": "레몬심리 저/박영란 역",
#       "pub": "갤리온",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   살고 싶다는 농담 : 허지웅 에세이(양장)",
#       "writer": "허지웅 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영 (리커버 특별판)(양장)-오늘의 젊은 작가",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   마법천자문 49  : 마주 보는 그림자! 그림자 영(影)!",
#       "writer": "유대영 글/홍거북 그림/김창환 감수",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   규칙 없음 : 넷플릭스, 지구상 가장 빠르고 유연한 기업의 비밀",
#       "writer": "리드 헤이스팅스,에린 마이어 저/이경남 역",
#       "pub": "알에이치코리아(RHK)",
#       "pubdate": "2020년 09월",
#       "price": "25000"
#     },
#     {
#       "title": "[도서]   어른의 어휘력 : 말에 품격을 더하고 세상을 올바르게 이해하는 힘",
#       "writer": "유선경 저",
#       "pub": "앤의서재",
#       "pubdate": "2020년 08월",
#       "price": "16500"
#     },
#     {
#       "title": "[도서]   완전학습 바이블 : 배운 것을 100% 이해하는 후천적 공부머리의 비밀(부모를 위한 습관노트 (포인트차감), [단독] 도서 포함 국내도서 2만원↑ 북 크로스 에코백 증정 (선착순, 포인트 차감))",
#       "writer": "임작가 저",
#       "pub": "다산에듀",
#       "pubdate": "2020년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   알사탕(양장)-그림책이 참 좋아 039",
#       "writer": "백희나 글그림",
#       "pub": "책읽는곰",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     }
#   ]
# }
# {
#   "books2": [
#     {
#       "title": "[도서]   이토록 공부가 재미있어지는 순간 : 공부에 지친 청소년들을 위한 힐링 에세이(30만 부 기념 Magic 에디션, 양장)",
#       "writer": "박성혁 저",
#       "pub": "다산북스",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   돈의 속성  : 최상위 부자가 말하는 돈에 대한 모든 것",
#       "writer": "김승호 저",
#       "pub": "스노우폭스북스",
#       "pubdate": "2020년 06월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   한번도 경험해보지 못한 나라 : \"민주주의는 어떻게 끝장나는가\"",
#       "writer": "강양구,권경애,김경율,서민,진중권 저",
#       "pub": "천년의상상",
#       "pubdate": "2020년 08월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   아몬드(양장)",
#       "writer": "손원평 저",
#       "pub": "창비",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   흔한남매의 흔한 호기심 1",
#       "writer": "흔한남매 원저/안치현 글/유난희 그림/이정모,흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   주식투자 무작정 따라하기 : 100만 왕초보가 감동한 최고의 주식투자 입문서(개정판)-길벗 무따기",
#       "writer": "윤재수 저",
#       "pub": "길벗",
#       "pubdate": "2020년 01월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   심판(양장,  마우스패드 증정 (포인트 차감))",
#       "writer": "베르나르 베르베르 저/전미연 역",
#       "pub": "열린책들",
#       "pubdate": "2020년 08월",
#       "price": "12800"
#     },
#     {
#       "title": "[도서]   존리의 부자되기 습관 : 대한민국 경제독립 액션 플랜(20만부 기념 리커버 에디션)",
#       "writer": "존리 저",
#       "pub": "지식노마드",
#       "pubdate": "2020년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 8 (양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   김미경의 리부트 : 코로나로 멈춘 나를 다시 일으켜 세우는 법",
#       "writer": "김미경 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 07월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   더 해빙 The Having (40만부 기념 리커버 에디션) : 부와 행운을 끌어당기는 힘(양장)",
#       "writer": "이서윤,홍주연 저",
#       "pub": "수오서재",
#       "pubdate": "2020년 03월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   만남은 지겹고 이별은 지쳤다 : 색과 체 산문집",
#       "writer": "색과 체 저",
#       "pub": "떠오름",
#       "pubdate": "2020년 06월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   기분이 태도가 되지 않게 : 기분 따라 행동하다 손해 보는 당신을 위한 심리 수업",
#       "writer": "레몬심리 저/박영란 역",
#       "pub": "갤리온",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   살고 싶다는 농담 : 허지웅 에세이(양장)",
#       "writer": "허지웅 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영 (리커버 특별판)(양장)-오늘의 젊은 작가",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   마법천자문 49  : 마주 보는 그림자! 그림자 영(影)!",
#       "writer": "유대영 글/홍거북 그림/김창환 감수",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   규칙 없음 : 넷플릭스, 지구상 가장 빠르고 유연한 기업의 비밀",
#       "writer": "리드 헤이스팅스,에린 마이어 저/이경남 역",
#       "pub": "알에이치코리아(RHK)",
#       "pubdate": "2020년 09월",
#       "price": "25000"
#     },
#     {
#       "title": "[도서]   어른의 어휘력 : 말에 품격을 더하고 세상을 올바르게 이해하는 힘",
#       "writer": "유선경 저",
#       "pub": "앤의서재",
#       "pubdate": "2020년 08월",
#       "price": "16500"
#     },
#     {
#       "title": "[도서]   완전학습 바이블 : 배운 것을 100% 이해하는 후천적 공부머리의 비밀(부모를 위한 습관노트 (포인트차감), [단독] 도서 포함 국내도서 2만원↑ 북 크로스 에코백 증정 (선착순, 포인트 차감))",
#       "writer": "임작가 저",
#       "pub": "다산에듀",
#       "pubdate": "2020년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   알사탕(양장)-그림책이 참 좋아 039",
#       "writer": "백희나 글그림",
#       "pub": "책읽는곰",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   애쓰지 않고 편안하게 (20만 부 기념 에디션)(먼슬리 스티키 노트 증정(포인트 차감))",
#       "writer": "김수현 저",
#       "pub": "놀",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코로나 사피엔스 : 문명의 대전환, 대한민국 대표 석학 6인이 신인류의 미래를 말한다(양장)-문재인 대통령 2020년 독서의 달 추천도서",
#       "writer": "최재천,장하준,최재붕,홍기빈,김누리,김경일,정관용 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2020년 06월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   철학의 숲 : 동화와 신화 속에 숨겨진 26가지 생각씨앗을 찾아서",
#       "writer": "브렌던 오도너휴 저/허성심 역",
#       "pub": "포레스트북스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   부의 대이동 : 달러와 금의 흐름으로 읽는 미래 투자 전략",
#       "writer": "오건영 저",
#       "pub": "페이지2",
#       "pubdate": "2020년 07월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   설민석의 세계사 대모험 6 : 인디펜던스 데이",
#       "writer": "설민석,잼스토리 글/박성일 그림",
#       "pub": "단꿈아이",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   마음챙김의 시",
#       "writer": "류시화 편",
#       "pub": "수오서재",
#       "pubdate": "2020년 09월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   상관없는 거 아닌가? : 장기하 산문('상관없는 투톤머그' 증정(포인트 차감))",
#       "writer": "장기하 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 09월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   Go Go 카카오프렌즈 16 베트남(부록 : 캐릭터 스티커(책과 랩핑))",
#       "writer": "김미영 글/김정한 그림",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   해커스 토익 기출 보카 : 주제별 연상암기로 토익 영단어 30일 완성! (단어암기어플, MP3, 실전문제 무료 제공, 개정판)-해커스 신토익",
#       "writer": "데이비드 조 저",
#       "pub": "해커스어학연구소",
#       "pubdate": "2020년 03월",
#       "price": "12900"
#     },
#     {
#       "title": "[도서]   장군이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   나는 너를 펭랑해 : 펭수 엽서책(펭러브 포스터, 데코 스티커 증정(각 포인트 차감))",
#       "writer": "EBS 저",
#       "pub": "EBS BOOKS",
#       "pubdate": "2020년 09월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   공부란 무엇인가",
#       "writer": "김영민 저",
#       "pub": "어크로스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   소원 떡집(양장)",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   달 샤베트(양장, 개정판)-그림책이 참 좋아 019",
#       "writer": "백희나 저",
#       "pub": "책읽는곰",
#       "pubdate": "2014년 05월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   초격차 : 리더의 질문 : 위기와 기회의 시대, 기업의 길을 묻다(양장)",
#       "writer": "권오현 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (상)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2019년 12월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   주식 부자 프로젝트 : 하루 만 원으로 시작하는",
#       "writer": "채상욱 저",
#       "pub": "비에이블",
#       "pubdate": "2020년 09월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   CHANGE 9 (체인지 나인) : 포노 사피엔스 코드",
#       "writer": "최재붕 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (하)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 01월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   설민석의 한국사 대모험 14 : 명의 허준 편 : 안녕, 로빈!(설쌤 친필 사인 메시지 인쇄본)",
#       "writer": "설민석,스토리박스 글/정현희 그림/태건 역사 연구소 감수",
#       "pub": "아이휴먼",
#       "pubdate": "2020년 07월",
#       "price": "12000"
#     }
#   ]
# }
# {
#   "books2": [
#     {
#       "title": "[도서]   이토록 공부가 재미있어지는 순간 : 공부에 지친 청소년들을 위한 힐링 에세이(30만 부 기념 Magic 에디션, 양장)",
#       "writer": "박성혁 저",
#       "pub": "다산북스",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   돈의 속성  : 최상위 부자가 말하는 돈에 대한 모든 것",
#       "writer": "김승호 저",
#       "pub": "스노우폭스북스",
#       "pubdate": "2020년 06월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   한번도 경험해보지 못한 나라 : \"민주주의는 어떻게 끝장나는가\"",
#       "writer": "강양구,권경애,김경율,서민,진중권 저",
#       "pub": "천년의상상",
#       "pubdate": "2020년 08월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   아몬드(양장)",
#       "writer": "손원평 저",
#       "pub": "창비",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   흔한남매의 흔한 호기심 1",
#       "writer": "흔한남매 원저/안치현 글/유난희 그림/이정모,흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   주식투자 무작정 따라하기 : 100만 왕초보가 감동한 최고의 주식투자 입문서(개정판)-길벗 무따기",
#       "writer": "윤재수 저",
#       "pub": "길벗",
#       "pubdate": "2020년 01월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   심판(양장,  마우스패드 증정 (포인트 차감))",
#       "writer": "베르나르 베르베르 저/전미연 역",
#       "pub": "열린책들",
#       "pubdate": "2020년 08월",
#       "price": "12800"
#     },
#     {
#       "title": "[도서]   존리의 부자되기 습관 : 대한민국 경제독립 액션 플랜(20만부 기념 리커버 에디션)",
#       "writer": "존리 저",
#       "pub": "지식노마드",
#       "pubdate": "2020년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 8 (양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   김미경의 리부트 : 코로나로 멈춘 나를 다시 일으켜 세우는 법",
#       "writer": "김미경 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 07월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   더 해빙 The Having (40만부 기념 리커버 에디션) : 부와 행운을 끌어당기는 힘(양장)",
#       "writer": "이서윤,홍주연 저",
#       "pub": "수오서재",
#       "pubdate": "2020년 03월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   만남은 지겹고 이별은 지쳤다 : 색과 체 산문집",
#       "writer": "색과 체 저",
#       "pub": "떠오름",
#       "pubdate": "2020년 06월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   기분이 태도가 되지 않게 : 기분 따라 행동하다 손해 보는 당신을 위한 심리 수업",
#       "writer": "레몬심리 저/박영란 역",
#       "pub": "갤리온",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   살고 싶다는 농담 : 허지웅 에세이(양장)",
#       "writer": "허지웅 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영 (리커버 특별판)(양장)-오늘의 젊은 작가",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   마법천자문 49  : 마주 보는 그림자! 그림자 영(影)!",
#       "writer": "유대영 글/홍거북 그림/김창환 감수",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   규칙 없음 : 넷플릭스, 지구상 가장 빠르고 유연한 기업의 비밀",
#       "writer": "리드 헤이스팅스,에린 마이어 저/이경남 역",
#       "pub": "알에이치코리아(RHK)",
#       "pubdate": "2020년 09월",
#       "price": "25000"
#     },
#     {
#       "title": "[도서]   어른의 어휘력 : 말에 품격을 더하고 세상을 올바르게 이해하는 힘",
#       "writer": "유선경 저",
#       "pub": "앤의서재",
#       "pubdate": "2020년 08월",
#       "price": "16500"
#     },
#     {
#       "title": "[도서]   완전학습 바이블 : 배운 것을 100% 이해하는 후천적 공부머리의 비밀(부모를 위한 습관노트 (포인트차감), [단독] 도서 포함 국내도서 2만원↑ 북 크로스 에코백 증정 (선착순, 포인트 차감))",
#       "writer": "임작가 저",
#       "pub": "다산에듀",
#       "pubdate": "2020년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   알사탕(양장)-그림책이 참 좋아 039",
#       "writer": "백희나 글그림",
#       "pub": "책읽는곰",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   애쓰지 않고 편안하게 (20만 부 기념 에디션)(먼슬리 스티키 노트 증정(포인트 차감))",
#       "writer": "김수현 저",
#       "pub": "놀",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코로나 사피엔스 : 문명의 대전환, 대한민국 대표 석학 6인이 신인류의 미래를 말한다(양장)-문재인 대통령 2020년 독서의 달 추천도서",
#       "writer": "최재천,장하준,최재붕,홍기빈,김누리,김경일,정관용 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2020년 06월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   철학의 숲 : 동화와 신화 속에 숨겨진 26가지 생각씨앗을 찾아서",
#       "writer": "브렌던 오도너휴 저/허성심 역",
#       "pub": "포레스트북스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   부의 대이동 : 달러와 금의 흐름으로 읽는 미래 투자 전략",
#       "writer": "오건영 저",
#       "pub": "페이지2",
#       "pubdate": "2020년 07월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   설민석의 세계사 대모험 6 : 인디펜던스 데이",
#       "writer": "설민석,잼스토리 글/박성일 그림",
#       "pub": "단꿈아이",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   마음챙김의 시",
#       "writer": "류시화 편",
#       "pub": "수오서재",
#       "pubdate": "2020년 09월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   상관없는 거 아닌가? : 장기하 산문('상관없는 투톤머그' 증정(포인트 차감))",
#       "writer": "장기하 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 09월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   Go Go 카카오프렌즈 16 베트남(부록 : 캐릭터 스티커(책과 랩핑))",
#       "writer": "김미영 글/김정한 그림",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   해커스 토익 기출 보카 : 주제별 연상암기로 토익 영단어 30일 완성! (단어암기어플, MP3, 실전문제 무료 제공, 개정판)-해커스 신토익",
#       "writer": "데이비드 조 저",
#       "pub": "해커스어학연구소",
#       "pubdate": "2020년 03월",
#       "price": "12900"
#     },
#     {
#       "title": "[도서]   장군이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   나는 너를 펭랑해 : 펭수 엽서책(펭러브 포스터, 데코 스티커 증정(각 포인트 차감))",
#       "writer": "EBS 저",
#       "pub": "EBS BOOKS",
#       "pubdate": "2020년 09월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   공부란 무엇인가",
#       "writer": "김영민 저",
#       "pub": "어크로스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   소원 떡집(양장)",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   달 샤베트(양장, 개정판)-그림책이 참 좋아 019",
#       "writer": "백희나 저",
#       "pub": "책읽는곰",
#       "pubdate": "2014년 05월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   초격차 : 리더의 질문 : 위기와 기회의 시대, 기업의 길을 묻다(양장)",
#       "writer": "권오현 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (상)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2019년 12월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   주식 부자 프로젝트 : 하루 만 원으로 시작하는",
#       "writer": "채상욱 저",
#       "pub": "비에이블",
#       "pubdate": "2020년 09월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   CHANGE 9 (체인지 나인) : 포노 사피엔스 코드",
#       "writer": "최재붕 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (하)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 01월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   설민석의 한국사 대모험 14 : 명의 허준 편 : 안녕, 로빈!(설쌤 친필 사인 메시지 인쇄본)",
#       "writer": "설민석,스토리박스 글/정현희 그림/태건 역사 연구소 감수",
#       "pub": "아이휴먼",
#       "pubdate": "2020년 07월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   매우 예민한 사람들을 위한 책 : 뇌과학과 정신의학이 들려주는 당신 마음에 대한 이야기(10만 부 기념 리커버, 양장, 고슴도치 마봉이 키링 증정)",
#       "writer": "전홍진 저",
#       "pub": "글항아리",
#       "pubdate": "2020년 07월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   대한민국 상가투자 지도 : 1일 매출로 보는",
#       "writer": "김종율 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2020년 09월",
#       "price": "19000"
#     },
#     {
#       "title": "[도서]   만복이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2010년 05월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   미움받을 용기 : 자유롭고 행복한 삶을 위한 아들러의 가르침",
#       "writer": "기시미 이치로,고가 후미타케 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2014년 11월",
#       "price": "14900"
#     },
#     {
#       "title": "[도서]   달러구트 꿈 백화점 : 주문하신 꿈은 매진입니다",
#       "writer": "이미예 저",
#       "pub": "팩토리나인",
#       "pubdate": "2020년 07월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   그 환자",
#       "writer": "재스퍼 드윗 저/서은원 역",
#       "pub": "시월이일",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   부의 인문학 : 슈퍼리치의 서재에서 찾아낸 부자의 길(큐브형 점착 메모지 증정 (포인트 차감, 한정수량))",
#       "writer": "브라운스톤(우석) 저",
#       "pub": "오픈마인드",
#       "pubdate": "2019년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서] 마흔 살에 시작하는  주식 공부 5일 완성",
#       "writer": "박민수(샌드타이거샤크) 저",
#       "pub": "한국경제신문i",
#       "pubdate": "2018년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   엄마, 주식 사주세요 (리커버 에디션) : 존리의 미래를 위한 투자 원칙(양장)",
#       "writer": "존리 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   딸은 엄마의 감정을 먹고 자란다 (리커버 에디션) : 세상의 모든 딸, 엄마, 여자를 위한 자기회복 심리학",
#       "writer": "박우란 저",
#       "pub": "유노라이프",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코스모스 : 특별판(포함 인문/사회/역사/과학/예술 2만원↑ 대용량 텀블러 증정(포인트 차감))",
#       "writer": "칼 세이건 저/홍승수 역",
#       "pub": "사이언스북스",
#       "pubdate": "2006년 12월",
#       "price": "18500"
#     },
#     {
#       "title": "[도서]   ETS 토익 정기시험 기출문제집 1000 Vol.2 READING 리딩(기출문제집+해설집+무료 어플 학습지원, 베이직 4섹션 노트 증정(택1/포인트 차감))-ETS 토익 정기시험 기출문제집",
#       "writer": "ETS 저",
#       "pub": "YBM(와이비엠)",
#       "pubdate": "2019년 12월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 기출 500제 한국사능력검정시험 심화(1·2·3급)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 07월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   흔한남매 5(양장)",
#       "writer": "흔한남매 원저/백난도 글/유난희 그림/흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 06월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   푸른 사자 와니니-창비아동문고 280",
#       "writer": "이현 글/오윤화 그림",
#       "pub": "창비",
#       "pubdate": "2015년 06월",
#       "price": "10800"
#     },
#     {
#       "title": "[도서]   하버드 상위 1퍼센트의 비밀 : 신호를 차단하고 깊이 몰입하라(리커버 에디션)",
#       "writer": "정주영 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2018년 10월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   페인트-창비 청소년 문학 089/창비청소년문학상 수상작",
#       "writer": "이희영 저",
#       "pub": "창비",
#       "pubdate": "2019년 04월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   열두 살에 부자가 된 키라(양장, 개정판)-꿈을 이루게 도와주는 자기경영 동화 01",
#       "writer": "보도 섀퍼 글/원유미 그림",
#       "pub": "을파소(21세기북스)",
#       "pubdate": "2014년 10월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   방구석 미술관 : 가볍고 편하게 시작하는 유쾌한 교양 미술(포함 예술 3만원↑ 마티스 패브릭 포스터 증정(포인트 차감))",
#       "writer": "조원재 저",
#       "pub": "블랙피쉬",
#       "pubdate": "2018년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   ETS 토익 정기시험 기출문제집 1000 Vol.2 LISTENING 리스닝(기출문제집+해설집+정기시험 성우 MP3 무료제공, 베이직 4섹션 노트 증정(택1/포인트 차감))-ETS 토익 정기시험 기출문제집",
#       "writer": "ETS 저",
#       "pub": "YBM(와이비엠)",
#       "pubdate": "2019년 12월",
#       "price": "17800"
#     }
#   ]
# }
# {
#   "books2": [
#     {
#       "title": "[도서]   이토록 공부가 재미있어지는 순간 : 공부에 지친 청소년들을 위한 힐링 에세이(30만 부 기념 Magic 에디션, 양장)",
#       "writer": "박성혁 저",
#       "pub": "다산북스",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   돈의 속성  : 최상위 부자가 말하는 돈에 대한 모든 것",
#       "writer": "김승호 저",
#       "pub": "스노우폭스북스",
#       "pubdate": "2020년 06월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   한번도 경험해보지 못한 나라 : \"민주주의는 어떻게 끝장나는가\"",
#       "writer": "강양구,권경애,김경율,서민,진중권 저",
#       "pub": "천년의상상",
#       "pubdate": "2020년 08월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   아몬드(양장)",
#       "writer": "손원평 저",
#       "pub": "창비",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   흔한남매의 흔한 호기심 1",
#       "writer": "흔한남매 원저/안치현 글/유난희 그림/이정모,흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   주식투자 무작정 따라하기 : 100만 왕초보가 감동한 최고의 주식투자 입문서(개정판)-길벗 무따기",
#       "writer": "윤재수 저",
#       "pub": "길벗",
#       "pubdate": "2020년 01월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   심판(양장,  마우스패드 증정 (포인트 차감))",
#       "writer": "베르나르 베르베르 저/전미연 역",
#       "pub": "열린책들",
#       "pubdate": "2020년 08월",
#       "price": "12800"
#     },
#     {
#       "title": "[도서]   존리의 부자되기 습관 : 대한민국 경제독립 액션 플랜(20만부 기념 리커버 에디션)",
#       "writer": "존리 저",
#       "pub": "지식노마드",
#       "pubdate": "2020년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 8 (양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   김미경의 리부트 : 코로나로 멈춘 나를 다시 일으켜 세우는 법",
#       "writer": "김미경 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 07월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   더 해빙 The Having (40만부 기념 리커버 에디션) : 부와 행운을 끌어당기는 힘(양장)",
#       "writer": "이서윤,홍주연 저",
#       "pub": "수오서재",
#       "pubdate": "2020년 03월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   만남은 지겹고 이별은 지쳤다 : 색과 체 산문집",
#       "writer": "색과 체 저",
#       "pub": "떠오름",
#       "pubdate": "2020년 06월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   기분이 태도가 되지 않게 : 기분 따라 행동하다 손해 보는 당신을 위한 심리 수업",
#       "writer": "레몬심리 저/박영란 역",
#       "pub": "갤리온",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   살고 싶다는 농담 : 허지웅 에세이(양장)",
#       "writer": "허지웅 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영 (리커버 특별판)(양장)-오늘의 젊은 작가",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   마법천자문 49  : 마주 보는 그림자! 그림자 영(影)!",
#       "writer": "유대영 글/홍거북 그림/김창환 감수",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   규칙 없음 : 넷플릭스, 지구상 가장 빠르고 유연한 기업의 비밀",
#       "writer": "리드 헤이스팅스,에린 마이어 저/이경남 역",
#       "pub": "알에이치코리아(RHK)",
#       "pubdate": "2020년 09월",
#       "price": "25000"
#     },
#     {
#       "title": "[도서]   어른의 어휘력 : 말에 품격을 더하고 세상을 올바르게 이해하는 힘",
#       "writer": "유선경 저",
#       "pub": "앤의서재",
#       "pubdate": "2020년 08월",
#       "price": "16500"
#     },
#     {
#       "title": "[도서]   완전학습 바이블 : 배운 것을 100% 이해하는 후천적 공부머리의 비밀(부모를 위한 습관노트 (포인트차감), [단독] 도서 포함 국내도서 2만원↑ 북 크로스 에코백 증정 (선착순, 포인트 차감))",
#       "writer": "임작가 저",
#       "pub": "다산에듀",
#       "pubdate": "2020년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   알사탕(양장)-그림책이 참 좋아 039",
#       "writer": "백희나 글그림",
#       "pub": "책읽는곰",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   애쓰지 않고 편안하게 (20만 부 기념 에디션)(먼슬리 스티키 노트 증정(포인트 차감))",
#       "writer": "김수현 저",
#       "pub": "놀",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코로나 사피엔스 : 문명의 대전환, 대한민국 대표 석학 6인이 신인류의 미래를 말한다(양장)-문재인 대통령 2020년 독서의 달 추천도서",
#       "writer": "최재천,장하준,최재붕,홍기빈,김누리,김경일,정관용 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2020년 06월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   철학의 숲 : 동화와 신화 속에 숨겨진 26가지 생각씨앗을 찾아서",
#       "writer": "브렌던 오도너휴 저/허성심 역",
#       "pub": "포레스트북스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   부의 대이동 : 달러와 금의 흐름으로 읽는 미래 투자 전략",
#       "writer": "오건영 저",
#       "pub": "페이지2",
#       "pubdate": "2020년 07월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   설민석의 세계사 대모험 6 : 인디펜던스 데이",
#       "writer": "설민석,잼스토리 글/박성일 그림",
#       "pub": "단꿈아이",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   마음챙김의 시",
#       "writer": "류시화 편",
#       "pub": "수오서재",
#       "pubdate": "2020년 09월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   상관없는 거 아닌가? : 장기하 산문('상관없는 투톤머그' 증정(포인트 차감))",
#       "writer": "장기하 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 09월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   Go Go 카카오프렌즈 16 베트남(부록 : 캐릭터 스티커(책과 랩핑))",
#       "writer": "김미영 글/김정한 그림",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   해커스 토익 기출 보카 : 주제별 연상암기로 토익 영단어 30일 완성! (단어암기어플, MP3, 실전문제 무료 제공, 개정판)-해커스 신토익",
#       "writer": "데이비드 조 저",
#       "pub": "해커스어학연구소",
#       "pubdate": "2020년 03월",
#       "price": "12900"
#     },
#     {
#       "title": "[도서]   장군이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   나는 너를 펭랑해 : 펭수 엽서책(펭러브 포스터, 데코 스티커 증정(각 포인트 차감))",
#       "writer": "EBS 저",
#       "pub": "EBS BOOKS",
#       "pubdate": "2020년 09월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   공부란 무엇인가",
#       "writer": "김영민 저",
#       "pub": "어크로스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   소원 떡집(양장)",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   달 샤베트(양장, 개정판)-그림책이 참 좋아 019",
#       "writer": "백희나 저",
#       "pub": "책읽는곰",
#       "pubdate": "2014년 05월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   초격차 : 리더의 질문 : 위기와 기회의 시대, 기업의 길을 묻다(양장)",
#       "writer": "권오현 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (상)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2019년 12월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   주식 부자 프로젝트 : 하루 만 원으로 시작하는",
#       "writer": "채상욱 저",
#       "pub": "비에이블",
#       "pubdate": "2020년 09월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   CHANGE 9 (체인지 나인) : 포노 사피엔스 코드",
#       "writer": "최재붕 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (하)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 01월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   설민석의 한국사 대모험 14 : 명의 허준 편 : 안녕, 로빈!(설쌤 친필 사인 메시지 인쇄본)",
#       "writer": "설민석,스토리박스 글/정현희 그림/태건 역사 연구소 감수",
#       "pub": "아이휴먼",
#       "pubdate": "2020년 07월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   매우 예민한 사람들을 위한 책 : 뇌과학과 정신의학이 들려주는 당신 마음에 대한 이야기(10만 부 기념 리커버, 양장, 고슴도치 마봉이 키링 증정)",
#       "writer": "전홍진 저",
#       "pub": "글항아리",
#       "pubdate": "2020년 07월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   대한민국 상가투자 지도 : 1일 매출로 보는",
#       "writer": "김종율 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2020년 09월",
#       "price": "19000"
#     },
#     {
#       "title": "[도서]   만복이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2010년 05월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   미움받을 용기 : 자유롭고 행복한 삶을 위한 아들러의 가르침",
#       "writer": "기시미 이치로,고가 후미타케 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2014년 11월",
#       "price": "14900"
#     },
#     {
#       "title": "[도서]   달러구트 꿈 백화점 : 주문하신 꿈은 매진입니다",
#       "writer": "이미예 저",
#       "pub": "팩토리나인",
#       "pubdate": "2020년 07월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   그 환자",
#       "writer": "재스퍼 드윗 저/서은원 역",
#       "pub": "시월이일",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   부의 인문학 : 슈퍼리치의 서재에서 찾아낸 부자의 길(큐브형 점착 메모지 증정 (포인트 차감, 한정수량))",
#       "writer": "브라운스톤(우석) 저",
#       "pub": "오픈마인드",
#       "pubdate": "2019년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서] 마흔 살에 시작하는  주식 공부 5일 완성",
#       "writer": "박민수(샌드타이거샤크) 저",
#       "pub": "한국경제신문i",
#       "pubdate": "2018년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   엄마, 주식 사주세요 (리커버 에디션) : 존리의 미래를 위한 투자 원칙(양장)",
#       "writer": "존리 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   딸은 엄마의 감정을 먹고 자란다 (리커버 에디션) : 세상의 모든 딸, 엄마, 여자를 위한 자기회복 심리학",
#       "writer": "박우란 저",
#       "pub": "유노라이프",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코스모스 : 특별판(포함 인문/사회/역사/과학/예술 2만원↑ 대용량 텀블러 증정(포인트 차감))",
#       "writer": "칼 세이건 저/홍승수 역",
#       "pub": "사이언스북스",
#       "pubdate": "2006년 12월",
#       "price": "18500"
#     },
#     {
#       "title": "[도서]   ETS 토익 정기시험 기출문제집 1000 Vol.2 READING 리딩(기출문제집+해설집+무료 어플 학습지원, 베이직 4섹션 노트 증정(택1/포인트 차감))-ETS 토익 정기시험 기출문제집",
#       "writer": "ETS 저",
#       "pub": "YBM(와이비엠)",
#       "pubdate": "2019년 12월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 기출 500제 한국사능력검정시험 심화(1·2·3급)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 07월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   흔한남매 5(양장)",
#       "writer": "흔한남매 원저/백난도 글/유난희 그림/흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 06월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   푸른 사자 와니니-창비아동문고 280",
#       "writer": "이현 글/오윤화 그림",
#       "pub": "창비",
#       "pubdate": "2015년 06월",
#       "price": "10800"
#     },
#     {
#       "title": "[도서]   하버드 상위 1퍼센트의 비밀 : 신호를 차단하고 깊이 몰입하라(리커버 에디션)",
#       "writer": "정주영 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2018년 10월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   페인트-창비 청소년 문학 089/창비청소년문학상 수상작",
#       "writer": "이희영 저",
#       "pub": "창비",
#       "pubdate": "2019년 04월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   열두 살에 부자가 된 키라(양장, 개정판)-꿈을 이루게 도와주는 자기경영 동화 01",
#       "writer": "보도 섀퍼 글/원유미 그림",
#       "pub": "을파소(21세기북스)",
#       "pubdate": "2014년 10월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   방구석 미술관 : 가볍고 편하게 시작하는 유쾌한 교양 미술(포함 예술 3만원↑ 마티스 패브릭 포스터 증정(포인트 차감))",
#       "writer": "조원재 저",
#       "pub": "블랙피쉬",
#       "pubdate": "2018년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   ETS 토익 정기시험 기출문제집 1000 Vol.2 LISTENING 리스닝(기출문제집+해설집+정기시험 성우 MP3 무료제공, 베이직 4섹션 노트 증정(택1/포인트 차감))-ETS 토익 정기시험 기출문제집",
#       "writer": "ETS 저",
#       "pub": "YBM(와이비엠)",
#       "pubdate": "2019년 12월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   시선으로부터,(하와이 에디션)",
#       "writer": "정세랑 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   설민석의 만만 한국사 1 : 선사 시대부터 삼국 시대까지",
#       "writer": "설민석,신지희 글/김덕영 그림",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서] 스타강사 사경인 회계사의  재무제표 모르면 주식투자 절대로 하지마라(개정증보판, ‘염블리 추천 투자 유망 종목 미니북’ 단독 증정 (포인트 차감, 한정수량))",
#       "writer": "사경인 저",
#       "pub": "베가북스",
#       "pubdate": "2020년 01월",
#       "price": "19800"
#     },
#     {
#       "title": "[도서]   전설로 떠나는 월가의 영웅 : 13년간 주식으로 단 한 해도 손실을 본 적이 없는 피터린치 투자법(양장, 개정판)",
#       "writer": "피터 린치,존 로스차일드 저/이건 역",
#       "pub": "국일증권경제연구소",
#       "pubdate": "2017년 04월",
#       "price": "23000"
#     },
#     {
#       "title": "[도서]   아는 만큼 당첨되는 청약의 기술 : 2030 싱글도, 무자녀 신혼부부도, 유주택자도 당첨되는 청약 5단계 전략",
#       "writer": "열정로즈(정숙희) 저",
#       "pub": "길벗",
#       "pubdate": "2020년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   나는 나로 살기로 했다 (100만 부 기념 클래식 에디션) : 냉담한 현실에서 어른살이를 위한 to do list(포함  2만원↑ 유리컵 증정(포인트 차감))",
#       "writer": "김수현 저",
#       "pub": "마음의숲",
#       "pubdate": "2016년 11월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   괜찮지 않은데 괜찮은 척했다",
#       "writer": "글배우 저/예란 그림",
#       "pub": "강한별",
#       "pubdate": "2020년 07월",
#       "price": "13500"
#     },
#     {
#       "title": "[도서]   체리새우 : 비밀글입니다-문학동네 청소년 042/문학동네 청소년문학상 수상작",
#       "writer": "황영미 저",
#       "pub": "문학동네",
#       "pubdate": "2019년 01월",
#       "price": "11500"
#     },
#     {
#       "title": "[도서]   성숙한 어른이 갖춰야 할 좋은 심리 습관",
#       "writer": "류쉬안 저/원녕경 역",
#       "pub": "다연",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영(양장, 포함 민음사 한국문학 2권 ↑ 디자인 비누 증정(포인트 차감))-오늘의 젊은 작가 09",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2015년 12월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   에이트 : 씽크 : 인공지능의 딥러닝을 이기는 동서양 천재들의 생각법(양장, 개정증보판)",
#       "writer": "이지성 저",
#       "pub": "차이정원",
#       "pubdate": "2020년 09월",
#       "price": "19800"
#     },
#     {
#       "title": "[도서]   코로나 이후의 세계 : 블룸버그 선정 세계 1위 미래학자 제이슨 솅커의 미래예측",
#       "writer": "제이슨 솅커 저/박성현 역",
#       "pub": "미디어숲",
#       "pubdate": "2020년 05월",
#       "price": "14800"
#     },
#     {
#       "title": "[도서]   2021 전한길 한국사 합격생 필기노트  : 공무원 9급 및 한국사능력검정시험 대비(개정판)",
#       "writer": "전한길 저",
#       "pub": "전한길한국사",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   지리의 힘 : 지리는 어떻게 개인의 운명을, 세계사를, 세계 경제를 좌우하는가",
#       "writer": "팀 마샬 저/김미선 역",
#       "pub": "사이",
#       "pubdate": "2016년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   사피엔스 : 유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문(저자 사인 인쇄본 )",
#       "writer": "유발 하라리 저/조현욱 역",
#       "pub": "김영사",
#       "pubdate": "2015년 11월",
#       "price": "22000"
#     },
#     {
#       "title": "[도서]   복자에게(양장, 작가 메시지 연필 증정 & 타자기 배지+편지지 세트 증정(각 포인트 차감))",
#       "writer": "김금희 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   프리즘",
#       "writer": "손원평 저",
#       "pub": "은행나무",
#       "pubdate": "2020년 09월",
#       "price": "13500"
#     },
#     {
#       "title": "[도서] 어린이를 위한 뇌과학 프로젝트  정재승의 인간탐구보고서 4 : 사춘기 땐 우리 모두 외계인(부록 : 뇌 말랑 보드게임 (책과랩핑), 양장, 마스크 스트랩 (포인트차감))",
#       "writer": "정재은,이고은 글/김현민 그림/정재승 기획",
#       "pub": "아울북",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   세계미래보고서 2035-2055 : 코로나19로 인해 앞당겨진 미래, 당신의 생존 전략을 재점검하라!",
#       "writer": "박영숙,제롬 글렌 저",
#       "pub": "교보문고",
#       "pubdate": "2020년 06월",
#       "price": "22000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 1(양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2019년 07월",
#       "price": "12000"
#     }
#   ]
# }
# {
#   "books2": [
#     {
#       "title": "[도서]   이토록 공부가 재미있어지는 순간 : 공부에 지친 청소년들을 위한 힐링 에세이(30만 부 기념 Magic 에디션, 양장)",
#       "writer": "박성혁 저",
#       "pub": "다산북스",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   돈의 속성  : 최상위 부자가 말하는 돈에 대한 모든 것",
#       "writer": "김승호 저",
#       "pub": "스노우폭스북스",
#       "pubdate": "2020년 06월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   한번도 경험해보지 못한 나라 : \"민주주의는 어떻게 끝장나는가\"",
#       "writer": "강양구,권경애,김경율,서민,진중권 저",
#       "pub": "천년의상상",
#       "pubdate": "2020년 08월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   아몬드(양장)",
#       "writer": "손원평 저",
#       "pub": "창비",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   흔한남매의 흔한 호기심 1",
#       "writer": "흔한남매 원저/안치현 글/유난희 그림/이정모,흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   주식투자 무작정 따라하기 : 100만 왕초보가 감동한 최고의 주식투자 입문서(개정판)-길벗 무따기",
#       "writer": "윤재수 저",
#       "pub": "길벗",
#       "pubdate": "2020년 01월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   심판(양장,  마우스패드 증정 (포인트 차감))",
#       "writer": "베르나르 베르베르 저/전미연 역",
#       "pub": "열린책들",
#       "pubdate": "2020년 08월",
#       "price": "12800"
#     },
#     {
#       "title": "[도서]   존리의 부자되기 습관 : 대한민국 경제독립 액션 플랜(20만부 기념 리커버 에디션)",
#       "writer": "존리 저",
#       "pub": "지식노마드",
#       "pubdate": "2020년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 8 (양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   김미경의 리부트 : 코로나로 멈춘 나를 다시 일으켜 세우는 법",
#       "writer": "김미경 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 07월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   더 해빙 The Having (40만부 기념 리커버 에디션) : 부와 행운을 끌어당기는 힘(양장)",
#       "writer": "이서윤,홍주연 저",
#       "pub": "수오서재",
#       "pubdate": "2020년 03월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   만남은 지겹고 이별은 지쳤다 : 색과 체 산문집",
#       "writer": "색과 체 저",
#       "pub": "떠오름",
#       "pubdate": "2020년 06월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   기분이 태도가 되지 않게 : 기분 따라 행동하다 손해 보는 당신을 위한 심리 수업",
#       "writer": "레몬심리 저/박영란 역",
#       "pub": "갤리온",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   살고 싶다는 농담 : 허지웅 에세이(양장)",
#       "writer": "허지웅 저",
#       "pub": "웅진지식하우스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영 (리커버 특별판)(양장)-오늘의 젊은 작가",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   마법천자문 49  : 마주 보는 그림자! 그림자 영(影)!",
#       "writer": "유대영 글/홍거북 그림/김창환 감수",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   규칙 없음 : 넷플릭스, 지구상 가장 빠르고 유연한 기업의 비밀",
#       "writer": "리드 헤이스팅스,에린 마이어 저/이경남 역",
#       "pub": "알에이치코리아(RHK)",
#       "pubdate": "2020년 09월",
#       "price": "25000"
#     },
#     {
#       "title": "[도서]   어른의 어휘력 : 말에 품격을 더하고 세상을 올바르게 이해하는 힘",
#       "writer": "유선경 저",
#       "pub": "앤의서재",
#       "pubdate": "2020년 08월",
#       "price": "16500"
#     },
#     {
#       "title": "[도서]   완전학습 바이블 : 배운 것을 100% 이해하는 후천적 공부머리의 비밀(부모를 위한 습관노트 (포인트차감), [단독] 도서 포함 국내도서 2만원↑ 북 크로스 에코백 증정 (선착순, 포인트 차감))",
#       "writer": "임작가 저",
#       "pub": "다산에듀",
#       "pubdate": "2020년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   알사탕(양장)-그림책이 참 좋아 039",
#       "writer": "백희나 글그림",
#       "pub": "책읽는곰",
#       "pubdate": "2017년 03월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   애쓰지 않고 편안하게 (20만 부 기념 에디션)(먼슬리 스티키 노트 증정(포인트 차감))",
#       "writer": "김수현 저",
#       "pub": "놀",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코로나 사피엔스 : 문명의 대전환, 대한민국 대표 석학 6인이 신인류의 미래를 말한다(양장)-문재인 대통령 2020년 독서의 달 추천도서",
#       "writer": "최재천,장하준,최재붕,홍기빈,김누리,김경일,정관용 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2020년 06월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   철학의 숲 : 동화와 신화 속에 숨겨진 26가지 생각씨앗을 찾아서",
#       "writer": "브렌던 오도너휴 저/허성심 역",
#       "pub": "포레스트북스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   부의 대이동 : 달러와 금의 흐름으로 읽는 미래 투자 전략",
#       "writer": "오건영 저",
#       "pub": "페이지2",
#       "pubdate": "2020년 07월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   설민석의 세계사 대모험 6 : 인디펜던스 데이",
#       "writer": "설민석,잼스토리 글/박성일 그림",
#       "pub": "단꿈아이",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   마음챙김의 시",
#       "writer": "류시화 편",
#       "pub": "수오서재",
#       "pubdate": "2020년 09월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   상관없는 거 아닌가? : 장기하 산문('상관없는 투톤머그' 증정(포인트 차감))",
#       "writer": "장기하 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 09월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   Go Go 카카오프렌즈 16 베트남(부록 : 캐릭터 스티커(책과 랩핑))",
#       "writer": "김미영 글/김정한 그림",
#       "pub": "아울북",
#       "pubdate": "2020년 09월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   해커스 토익 기출 보카 : 주제별 연상암기로 토익 영단어 30일 완성! (단어암기어플, MP3, 실전문제 무료 제공, 개정판)-해커스 신토익",
#       "writer": "데이비드 조 저",
#       "pub": "해커스어학연구소",
#       "pubdate": "2020년 03월",
#       "price": "12900"
#     },
#     {
#       "title": "[도서]   장군이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   나는 너를 펭랑해 : 펭수 엽서책(펭러브 포스터, 데코 스티커 증정(각 포인트 차감))",
#       "writer": "EBS 저",
#       "pub": "EBS BOOKS",
#       "pubdate": "2020년 09월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   공부란 무엇인가",
#       "writer": "김영민 저",
#       "pub": "어크로스",
#       "pubdate": "2020년 08월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   소원 떡집(양장)",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2020년 04월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   달 샤베트(양장, 개정판)-그림책이 참 좋아 019",
#       "writer": "백희나 저",
#       "pub": "책읽는곰",
#       "pubdate": "2014년 05월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   초격차 : 리더의 질문 : 위기와 기회의 시대, 기업의 길을 묻다(양장)",
#       "writer": "권오현 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (상)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2019년 12월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   주식 부자 프로젝트 : 하루 만 원으로 시작하는",
#       "writer": "채상욱 저",
#       "pub": "비에이블",
#       "pubdate": "2020년 09월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   CHANGE 9 (체인지 나인) : 포노 사피엔스 코드",
#       "writer": "최재붕 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 한국사능력검정시험 심화 (하)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 01월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   설민석의 한국사 대모험 14 : 명의 허준 편 : 안녕, 로빈!(설쌤 친필 사인 메시지 인쇄본)",
#       "writer": "설민석,스토리박스 글/정현희 그림/태건 역사 연구소 감수",
#       "pub": "아이휴먼",
#       "pubdate": "2020년 07월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   매우 예민한 사람들을 위한 책 : 뇌과학과 정신의학이 들려주는 당신 마음에 대한 이야기(10만 부 기념 리커버, 양장, 고슴도치 마봉이 키링 증정)",
#       "writer": "전홍진 저",
#       "pub": "글항아리",
#       "pubdate": "2020년 07월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   대한민국 상가투자 지도 : 1일 매출로 보는",
#       "writer": "김종율 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2020년 09월",
#       "price": "19000"
#     },
#     {
#       "title": "[도서]   만복이네 떡집(양장)-난 책읽기가 좋아",
#       "writer": "김리리 글/이승현 그림",
#       "pub": "비룡소",
#       "pubdate": "2010년 05월",
#       "price": "9500"
#     },
#     {
#       "title": "[도서]   미움받을 용기 : 자유롭고 행복한 삶을 위한 아들러의 가르침",
#       "writer": "기시미 이치로,고가 후미타케 저",
#       "pub": "인플루엔셜",
#       "pubdate": "2014년 11월",
#       "price": "14900"
#     },
#     {
#       "title": "[도서]   달러구트 꿈 백화점 : 주문하신 꿈은 매진입니다",
#       "writer": "이미예 저",
#       "pub": "팩토리나인",
#       "pubdate": "2020년 07월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   그 환자",
#       "writer": "재스퍼 드윗 저/서은원 역",
#       "pub": "시월이일",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   부의 인문학 : 슈퍼리치의 서재에서 찾아낸 부자의 길(큐브형 점착 메모지 증정 (포인트 차감, 한정수량))",
#       "writer": "브라운스톤(우석) 저",
#       "pub": "오픈마인드",
#       "pubdate": "2019년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서] 마흔 살에 시작하는  주식 공부 5일 완성",
#       "writer": "박민수(샌드타이거샤크) 저",
#       "pub": "한국경제신문i",
#       "pubdate": "2018년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   엄마, 주식 사주세요 (리커버 에디션) : 존리의 미래를 위한 투자 원칙(양장)",
#       "writer": "존리 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   딸은 엄마의 감정을 먹고 자란다 (리커버 에디션) : 세상의 모든 딸, 엄마, 여자를 위한 자기회복 심리학",
#       "writer": "박우란 저",
#       "pub": "유노라이프",
#       "pubdate": "2020년 07월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   코스모스 : 특별판(포함 인문/사회/역사/과학/예술 2만원↑ 대용량 텀블러 증정(포인트 차감))",
#       "writer": "칼 세이건 저/홍승수 역",
#       "pub": "사이언스북스",
#       "pubdate": "2006년 12월",
#       "price": "18500"
#     },
#     {
#       "title": "[도서]   ETS 토익 정기시험 기출문제집 1000 Vol.2 READING 리딩(기출문제집+해설집+무료 어플 학습지원, 베이직 4섹션 노트 증정(택1/포인트 차감))-ETS 토익 정기시험 기출문제집",
#       "writer": "ETS 저",
#       "pub": "YBM(와이비엠)",
#       "pubdate": "2019년 12월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   큰별쌤 최태성의 별★별 한국사 기출 500제 한국사능력검정시험 심화(1·2·3급)",
#       "writer": "최태성 저",
#       "pub": "이투스북",
#       "pubdate": "2020년 07월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   흔한남매 5(양장)",
#       "writer": "흔한남매 원저/백난도 글/유난희 그림/흔한컴퍼니 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 06월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   푸른 사자 와니니-창비아동문고 280",
#       "writer": "이현 글/오윤화 그림",
#       "pub": "창비",
#       "pubdate": "2015년 06월",
#       "price": "10800"
#     },
#     {
#       "title": "[도서]   하버드 상위 1퍼센트의 비밀 : 신호를 차단하고 깊이 몰입하라(리커버 에디션)",
#       "writer": "정주영 저",
#       "pub": "한국경제신문사(한경비피)",
#       "pubdate": "2018년 10월",
#       "price": "16000"
#     },
#     {
#       "title": "[도서]   페인트-창비 청소년 문학 089/창비청소년문학상 수상작",
#       "writer": "이희영 저",
#       "pub": "창비",
#       "pubdate": "2019년 04월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   열두 살에 부자가 된 키라(양장, 개정판)-꿈을 이루게 도와주는 자기경영 동화 01",
#       "writer": "보도 섀퍼 글/원유미 그림",
#       "pub": "을파소(21세기북스)",
#       "pubdate": "2014년 10월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   방구석 미술관 : 가볍고 편하게 시작하는 유쾌한 교양 미술(포함 예술 3만원↑ 마티스 패브릭 포스터 증정(포인트 차감))",
#       "writer": "조원재 저",
#       "pub": "블랙피쉬",
#       "pubdate": "2018년 08월",
#       "price": "16800"
#     },
#     {
#       "title": "[도서]   ETS 토익 정기시험 기출문제집 1000 Vol.2 LISTENING 리스닝(기출문제집+해설집+정기시험 성우 MP3 무료제공, 베이직 4섹션 노트 증정(택1/포인트 차감))-ETS 토익 정기시험 기출문제집",
#       "writer": "ETS 저",
#       "pub": "YBM(와이비엠)",
#       "pubdate": "2019년 12월",
#       "price": "17800"
#     },
#     {
#       "title": "[도서]   시선으로부터,(하와이 에디션)",
#       "writer": "정세랑 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   설민석의 만만 한국사 1 : 선사 시대부터 삼국 시대까지",
#       "writer": "설민석,신지희 글/김덕영 그림",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서] 스타강사 사경인 회계사의  재무제표 모르면 주식투자 절대로 하지마라(개정증보판, ‘염블리 추천 투자 유망 종목 미니북’ 단독 증정 (포인트 차감, 한정수량))",
#       "writer": "사경인 저",
#       "pub": "베가북스",
#       "pubdate": "2020년 01월",
#       "price": "19800"
#     },
#     {
#       "title": "[도서]   전설로 떠나는 월가의 영웅 : 13년간 주식으로 단 한 해도 손실을 본 적이 없는 피터린치 투자법(양장, 개정판)",
#       "writer": "피터 린치,존 로스차일드 저/이건 역",
#       "pub": "국일증권경제연구소",
#       "pubdate": "2017년 04월",
#       "price": "23000"
#     },
#     {
#       "title": "[도서]   아는 만큼 당첨되는 청약의 기술 : 2030 싱글도, 무자녀 신혼부부도, 유주택자도 당첨되는 청약 5단계 전략",
#       "writer": "열정로즈(정숙희) 저",
#       "pub": "길벗",
#       "pubdate": "2020년 09월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   나는 나로 살기로 했다 (100만 부 기념 클래식 에디션) : 냉담한 현실에서 어른살이를 위한 to do list(포함  2만원↑ 유리컵 증정(포인트 차감))",
#       "writer": "김수현 저",
#       "pub": "마음의숲",
#       "pubdate": "2016년 11월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   괜찮지 않은데 괜찮은 척했다",
#       "writer": "글배우 저/예란 그림",
#       "pub": "강한별",
#       "pubdate": "2020년 07월",
#       "price": "13500"
#     },
#     {
#       "title": "[도서]   체리새우 : 비밀글입니다-문학동네 청소년 042/문학동네 청소년문학상 수상작",
#       "writer": "황영미 저",
#       "pub": "문학동네",
#       "pubdate": "2019년 01월",
#       "price": "11500"
#     },
#     {
#       "title": "[도서]   성숙한 어른이 갖춰야 할 좋은 심리 습관",
#       "writer": "류쉬안 저/원녕경 역",
#       "pub": "다연",
#       "pubdate": "2020년 05월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   보건교사 안은영(양장, 포함 민음사 한국문학 2권 ↑ 디자인 비누 증정(포인트 차감))-오늘의 젊은 작가 09",
#       "writer": "정세랑 저",
#       "pub": "민음사",
#       "pubdate": "2015년 12월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   에이트 : 씽크 : 인공지능의 딥러닝을 이기는 동서양 천재들의 생각법(양장, 개정증보판)",
#       "writer": "이지성 저",
#       "pub": "차이정원",
#       "pubdate": "2020년 09월",
#       "price": "19800"
#     },
#     {
#       "title": "[도서]   코로나 이후의 세계 : 블룸버그 선정 세계 1위 미래학자 제이슨 솅커의 미래예측",
#       "writer": "제이슨 솅커 저/박성현 역",
#       "pub": "미디어숲",
#       "pubdate": "2020년 05월",
#       "price": "14800"
#     },
#     {
#       "title": "[도서]   2021 전한길 한국사 합격생 필기노트  : 공무원 9급 및 한국사능력검정시험 대비(개정판)",
#       "writer": "전한길 저",
#       "pub": "전한길한국사",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   지리의 힘 : 지리는 어떻게 개인의 운명을, 세계사를, 세계 경제를 좌우하는가",
#       "writer": "팀 마샬 저/김미선 역",
#       "pub": "사이",
#       "pubdate": "2016년 08월",
#       "price": "17000"
#     },
#     {
#       "title": "[도서]   사피엔스 : 유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문(저자 사인 인쇄본 )",
#       "writer": "유발 하라리 저/조현욱 역",
#       "pub": "김영사",
#       "pubdate": "2015년 11월",
#       "price": "22000"
#     },
#     {
#       "title": "[도서]   복자에게(양장, 작가 메시지 연필 증정 & 타자기 배지+편지지 세트 증정(각 포인트 차감))",
#       "writer": "김금희 저",
#       "pub": "문학동네",
#       "pubdate": "2020년 09월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   프리즘",
#       "writer": "손원평 저",
#       "pub": "은행나무",
#       "pubdate": "2020년 09월",
#       "price": "13500"
#     },
#     {
#       "title": "[도서] 어린이를 위한 뇌과학 프로젝트  정재승의 인간탐구보고서 4 : 사춘기 땐 우리 모두 외계인(부록 : 뇌 말랑 보드게임 (책과랩핑), 양장, 마스크 스트랩 (포인트차감))",
#       "writer": "정재은,이고은 글/김현민 그림/정재승 기획",
#       "pub": "아울북",
#       "pubdate": "2020년 08월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   세계미래보고서 2035-2055 : 코로나19로 인해 앞당겨진 미래, 당신의 생존 전략을 재점검하라!",
#       "writer": "박영숙,제롬 글렌 저",
#       "pub": "교보문고",
#       "pubdate": "2020년 06월",
#       "price": "22000"
#     },
#     {
#       "title": "[도서]   이상한 과자 가게 전천당 1(양장)",
#       "writer": "히로시마 레이코 글/쟈쟈 그림/김정화 역",
#       "pub": "길벗스쿨",
#       "pubdate": "2019년 07월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   이기적 유전자 The Selfish Gene(40주년 기념판, 개정판)",
#       "writer": "리처드 도킨스 저/홍영남,이상임 역",
#       "pub": "을유문화사",
#       "pubdate": "2018년 10월",
#       "price": "20000"
#     },
#     {
#       "title": "[도서]   리더라면 정조처럼 : 정조대왕의 숨겨진 리더십 코드 5049-문재인 대통령 2020년 독서의 달 추천도서",
#       "writer": "김준혁 저",
#       "pub": "더봄",
#       "pubdate": "2020년 06월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   정부가 집값을 안 잡는 이유",
#       "writer": "윤세경 저",
#       "pub": "이레퍼블리싱",
#       "pubdate": "2020년 09월",
#       "price": "14500"
#     },
#     {
#       "title": "[도서]   내가 들어보지 못해서, 아이에게 해주지 못한 말들 : 5,000가정을 변화시킨 정신과 의사의 따뜻한 대화 습관 28([단독] 홀로그램 티코스터 +  마스크 지퍼 케이스 (포인트차감))",
#       "writer": "다나카 시게키 저/장민주 역",
#       "pub": "길벗",
#       "pubdate": "2020년 09월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   우리가 빛의 속도로 갈 수 없다면(양장, 포함 소설/시 2만원↑ 패브릭포스터, 비누 증정 (각 포인트 차감, 선착순 한정))",
#       "writer": "김초엽 저",
#       "pub": "허블",
#       "pubdate": "2019년 06월",
#       "price": "14000"
#     },
#     {
#       "title": "[도서]   영원의 사자들 1,2 세트(전2권, 금장 책갈피 증정, 포함 소설/시 2만원 구매 시 방향제 증정 (각 포인트 차감, 선착순 한정 증정))",
#       "writer": "정은궐 저",
#       "pub": "파란 (파란미디어)",
#       "pubdate": "2020년 09월",
#       "price": "30000"
#     },
#     {
#       "title": "[만화]   원피스 ONE PIECE 97 : 나의 바이블",
#       "writer": "오다 에이이치로 글그림",
#       "pub": "대원",
#       "pubdate": "2020년 09월",
#       "price": "5000"
#     },
#     {
#       "title": "[도서]   페스트-민음사 세계문학전집 267",
#       "writer": "알베르 까뮈 저/김화영 역",
#       "pub": "민음사",
#       "pubdate": "2011년 03월",
#       "price": "13000"
#     },
#     {
#       "title": "[도서]   진짜 진짜 얼굴을 찾아서 : 고문영 동화(부록 : 상태 드로잉 노트, 양장)-사이코지만 괜찮아 특별 동화 시리즈 5",
#       "writer": "조용 저/잠산 그림",
#       "pub": "위즈덤하우스",
#       "pubdate": "2020년 08월",
#       "price": "12000"
#     },
#     {
#       "title": "[도서]   에듀윌 한국사능력검정시험 2주끝장 심화(1, 2, 3급)(온라인강의 무료제공)",
#       "writer": "에듀윌 한국사교육연구소 편저",
#       "pub": "에듀윌",
#       "pubdate": "2020년 03월",
#       "price": "21000"
#     },
#     {
#       "title": "[도서]   하루 10분의 기적 초등 패턴 글쓰기 : 아이의 글머리가 5일 안에 완성된다!",
#       "writer": "남낙현 저",
#       "pub": "청림Life",
#       "pubdate": "2020년 09월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   무엇을 위해 살죠? : 박진영 에세이(친필 인쇄 사인본, 양장)",
#       "writer": "박진영 저",
#       "pub": "은행나무",
#       "pubdate": "2020년 08월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   죽은 자의 집 청소(양장)",
#       "writer": "김완 저",
#       "pub": "김영사",
#       "pubdate": "2020년 05월",
#       "price": "13800"
#     },
#     {
#       "title": "[도서]   당신의 인생을 정리해드립니다 : 삶이 바뀌는 신박한 정리",
#       "writer": "이지영 저",
#       "pub": "쌤앤파커스",
#       "pubdate": "2020년 10월",
#       "price": "15000"
#     },
#     {
#       "title": "[도서]   시간을 파는 상점-자음과모음 청소년문학 15/자음과모음 청소년문학상 수상작",
#       "writer": "김선영 저",
#       "pub": "자음과모음",
#       "pubdate": "2012년 04월",
#       "price": "11000"
#     },
#     {
#       "title": "[도서]   하루만 네가 되고 싶어 1 특별판(부록: 사인 인쇄본+양면일러스트책갈피+특별판 케이스+별책부록+아크릴스탠드+어나더커버+일러스트엽서세트, 컬러)",
#       "writer": "삼 글그림",
#       "pub": "문학동네",
#       "pubdate": "2020년 11월",
#       "price": "36000"
#     },
#     {
#       "title": "[도서]   아비투스 : 인간의 품격을 결정하는 7가지 자본",
#       "writer": "도리스 메르틴 저/배명자 역",
#       "pub": "다산초당",
#       "pubdate": "2020년 08월",
#       "price": "18000"
#     },
#     {
#       "title": "[도서]   내일은 실험왕 50 : 빅뱅 우주론(부록 : 우주 성운 만들기 실험 키트)",
#       "writer": "스토리 a. 글/홍종현 그림/이창덕,박완규 감수",
#       "pub": "미래엔아이세움",
#       "pubdate": "2020년 08월",
#       "price": "12800"
#     },
#     {
#       "title": "[도서]   부자 아빠 가난한 아빠 20주년 특별 기념판-부자 아빠 가난한 아빠",
#       "writer": "로버트 기요사키 저/안진환 역",
#       "pub": "민음인",
#       "pubdate": "2018년 02월",
#       "price": "15800"
#     },
#     {
#       "title": "[도서]   1분 과학 : 세상에서 가장 놀라운 꿀잼 과학 이야기",
#       "writer": "이재범 저/최준석 그림",
#       "pub": "위즈덤하우스",
#       "pubdate": "2020년 09월",
#       "price": "16800"
#     }
#   ]
# }
